# %%
def create_account(name, initial_balance=0.0):
    account = {
        "name": name,
        "balance": initial_balance,
        "transactions": []
    }
    return account
def deposit(account, amount):
    if amount <= 0:
        print("Deposit amount must be positive.")
        return
    
    account["balance"] += amount
    transaction = f"Deposited: {amount}, New balance: {account['balance']}\n"
    account["transactions"].append(transaction)
    
    # Writing transaction to a file
    with open(f"{account['name']}_transactions.txt", "a") as file:
        file.write(transaction)
    
    print(f"Deposit successful! New balance: {account['balance']}")
def withdraw(account, amount):
    if amount <= 0:
        print("Withdrawal amount must be positive.")
        return
    
    if amount > account["balance"]:
        print("Insufficient balance.")
        return
    
    account["balance"] -= amount
    transaction = f"Withdrew: {amount}, New balance: {account['balance']}\n"
    account["transactions"].append(transaction)
    
    # Writing transaction to a file
    with open(f"{account['name']}_transactions.txt", "a") as file:
        file.write(transaction)
    
    print(f"Withdrawal successful! New balance: {account['balance']}")
def check_balance(account):
    print(f"Current balance: {account['balance']}")
def print_statement(account):
    print(f"Transaction statement for {account['name']}:")
    for transaction in account["transactions"]:
        print(transaction)
def main():
    # Creating an account
    account_name = input("Enter account holder's name: ")
    account = create_account(account_name)
    
    while True:
        print("\nMeezan bank menegment system:")
        print("1. Deposit Money")
        print("2. Withdraw Money")
        print("3. Check Balance")
        print("4. Print Transaction Statement")
        print("5. Exit")
        
        choice = input("Enter your choice: ")
        
        if choice == "1":
            amount = float(input("Enter deposit amount: "))
            deposit(account, amount)
        
        elif choice == "2":
            amount = float(input("Enter withdrawal amount: "))
            withdraw(account, amount)
        
        elif choice == "3":
            check_balance(account)
        
        elif choice == "4":
            print_statement(account)
        
        elif choice == "5":
            print("Thank you for using the banking system!")
            break
        else:
            print("Invalid choice. Please try again.")

# Run the program
main()
# Out:
# Enter account holder's name: siraj khan
#
# Banking System Menu:
# 1. Deposit Money
# 2. Withdraw Money
# 3. Check Balance
# 4. Print Transaction Statement
# 5. Exit
# Enter your choice: 1
# Enter deposit amount: 45
# Deposit successful! New balance: 45.0
#
# Banking System Menu:
# 1. Deposit Money
# 2. Withdraw Money
# 3. Check Balance
# 4. Print Transaction Statement
# 5. Exit
# Enter your choice: 1
# Enter deposit amount: 454
# Deposit successful! New balance: 499.0
#
# Banking System Menu:
# 1. Deposit Money
# 2. Withdraw Money
# 3. Check Balance
# 4. Print Transaction Statement
# 5. Exit
# Enter your choice: 2
# Enter withdrawal amount: 6
# Withdrawal successful! New balance: 493.0
#
# Banking System Menu:
# 1. Deposit Money
# 2. Withdraw Money
# 3. Check Balance
# 4. Print Transaction Statement
# 5. Exit
# Enter your choice: 2
# Enter withdrawal amount: 6
# Withdrawal successful! New balance: 487.0
#
# Banking System Menu:
# 1. Deposit Money
# 2. Withdraw Money
# 3. Check Balance
# 4. Print Transaction Statement
# 5. Exit
# Enter your choice: 4
# Transaction statement for siraj khan:
# Deposited: 45.0, New balance: 45.0
#
# Deposited: 454.0, New balance: 499.0
#
# Withdrew: 6.0, New balance: 493.0
#
# Withdrew: 6.0, New balance: 487.0
#
#
# Banking System Menu:
# 1. Deposit Money
# 2. Withdraw Money
# 3. Check Balance
# 4. Print Transaction Statement
# 5. Exit
# Enter your choice: 5
# Thank you for using the banking system!
